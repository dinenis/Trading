# %%
from web3 import Web3
import json
import numpy as np
from moralis import evm_api
import datetime
import pandas as pd
import plotly.express as px

# %%
decimals_USDC = 6
decimals_WETH = 18
tokenID = 29944

# %%
from constants import NFT_POSITIONMANAGER_CONTRACT_ADDRESS, NFT_POSITIONMANAGER_CONTRACT_ABI

NODE_PROVIDER='https://eth-mainnet.g.alchemy.com/v2/kqq6YvePSbVVpqEq_BeUTK9VOB8aO9e9'
web3_connection = Web3(Web3.HTTPProvider(NODE_PROVIDER))

NFT_POSITIONMANAGER_contract_abi = json.loads(NFT_POSITIONMANAGER_CONTRACT_ABI)
NFT_POSITIONMANAGER_contract = web3_connection.eth.contract(address=NFT_POSITIONMANAGER_CONTRACT_ADDRESS, abi=NFT_POSITIONMANAGER_contract_abi)

# %%
from constants import UNIV3_USDC_WETH_CONTRACT_ADDRESS, UNIV3_USDC_WETH_CONTRACT_ABI

UNIV3_USDC_WETH_contract_abi = json.loads(UNIV3_USDC_WETH_CONTRACT_ABI)
UNIV3_USDC_WETH_contract = web3_connection.eth.contract(address=UNIV3_USDC_WETH_CONTRACT_ADDRESS, abi=UNIV3_USDC_WETH_contract_abi)

# %% [markdown]
# We start by querying events so we query how much liquidity we add and at what block. Then we query when we decrease, how much liquidity we pull out.

# %%
latest = web3_connection.eth.get_block_number()
event_filter = NFT_POSITIONMANAGER_contract.events.IncreaseLiquidity.create_filter(fromBlock=0, toBlock=latest, argument_filters = {'tokenId': tokenID})
res = event_filter.get_all_entries()

# %%
event_filter = NFT_POSITIONMANAGER_contract.events.DecreaseLiquidity.create_filter(fromBlock=0, toBlock=latest, argument_filters = {'tokenId': tokenID})
res2 = event_filter.get_all_entries()

# %% [markdown]
# Call collect event. Collect event contains the funds we pulled out plus the interest. Some actions trigger events which are recorded on chain. Transactions on Eth scan.

# %%
if len(res2) == 0:
    endTime = datetime.datetime.now().replace(microsecond=0)
else:
    blockNumber_end = res2[-1]['blockNumber']
    liquidity_end = NFT_POSITIONMANAGER_contract.functions.positions(tokenID).call(block_identifier=blockNumber_end)[7]
    if liquidity_end == 0:
        endTime = datetime.datetime.fromtimestamp(web3_connection.eth.get_block(blockNumber_end).timestamp)
        event_filter = NFT_POSITIONMANAGER_contract.events.Collect.create_filter(fromBlock=0, toBlock=latest, argument_filters = {'tokenId': tokenID})
        res3 = event_filter.get_all_entries()
        amount0_burned = res2[-1]['args']['amount0']
        amount1_burned = res2[-1]['args']['amount1']
        amount0_collected = res3[-1]['args']['amount0']
        amount1_collected = res3[-1]['args']['amount1']
    else:
        endTime = datetime.datetime.now().replace(microsecond=0)

# %%
res
# Out:
# [AttributeDict({'args': AttributeDict({'tokenId': 29944,
#    'liquidity': 642845769648974884,
#    'amount0': 3824486509842431902924,
#    'amount1': 7645663666271}),
#   'event': 'IncreaseLiquidity',
#   'logIndex': 350,
#   'transactionIndex': 155,
#   'transactionHash': HexBytes('0x85511f0cb38d1808dfdd3cdd5e5c3c713aa436dc98967ce54ad9c9ef1686e44f'),
#   'address': '0xC36442b4a4522E871399CD717aBDD847Ab11FE88',
#   'blockHash': HexBytes('0x654ee650697ab1d23650f368e29a2fcbe93dcfbdf79fbc704400aea55aac9011'),
#   'blockNumber': 12540024}),
#  AttributeDict({'args': AttributeDict({'tokenId': 29944,
#    'liquidity': 1609629190976361,
#    'amount0': 7999999999998472686,
#    'amount1': 22952036523}),
#   'event': 'IncreaseLiquidity',
#   'logIndex': 221,
#   'transactionIndex': 174,
#   'transactionHash': HexBytes('0x9f272b54ce441da52382716f33c1c304e20478c11e108ebaed662c663246e9a4'),
#   'address': '0xC36442b4a4522E871399CD717aBDD847Ab11FE88',
#   'blockHash': HexBytes('0x280d6ad75c13da66ec9f208c5e9dc84c8de14a7ac9ccdf642d3ee6a41fde32b7'),
#   'blockNumber': 12549923}),
#  AttributeDict({'args': AttributeDict({'tokenId': 29944,
#    'liquidity': 983914297756719,
#    'amount0': 3999999999770286393,
#    'amount1': 16394098685}),
#   'event': 'IncreaseLiquidity',
#   'logIndex': 196,
#   'transactionIndex': 89,
#   'transactionHash': HexBytes('0x34c196566abad478f177ddf569d754e29e54d02728ebd8f8135a877f2bc9eb96'),
#   'address': '0xC36442b4a4522E871399CD717aBDD847Ab11FE88',
#   'blockHash': HexBytes('0xb39d5755dcdd55c528b64c6af0c2279f1c5d2eea8073abc8597a9b0467d340aa'),
#   'blockNumber': 12559665}),
#  AttributeDict({'args': AttributeDict({'tokenId': 29944,
#    'liquidity': 1084087262173046,
#    'amount0': 4999999999779942005,
#    'amount1': 16459906752}),
#   'event': 'IncreaseLiquidity',
#   'logIndex': 39,
#   'transactionIndex': 26,
#   'transactionHash': HexBytes('0xfd865f276b2dd449a8fc0d5b53e4a72fc88870d1b5a2debad0c6719fe60e74e5'),
#   'address': '0xC36442b4a4522E871399CD717aBDD847Ab11FE88',
#   'blockHash': HexBytes('0xa06e17e60bfe384119b46bda5e2dc9bdf6776bbe0f300a8044e1fe6b32435c71'),
#   'blockNumber': 12567600}),
#  AttributeDict({'args': AttributeDict({'tokenId': 29944,
#    'liquidity': 912694825737065,
#    'amount0': 4231453363560412420,
#    'amount1': 13800000000}),
#   'event': 'IncreaseLiquidity',
#   'logIndex': 24,
#   'transactionIndex': 8,
#   'transactionHash': HexBytes('0xe0e25dc10605df10513ded0a31f4c08f564064280d06d9e2951c6792b22d67b2'),
#   'address': '0xC36442b4a4522E871399CD717aBDD847Ab11FE88',
#   'blockHash': HexBytes('0xcf84b799d2b8498229253617d97ac034e5cfc87b21f756e09406c5a5d7a5fada'),
#   'blockNumber': 12574948}),
#  AttributeDict({'args': AttributeDict({'tokenId': 29944,
#    'liquidity': 1568234529432004,
#    'amount0': 7937632652259519757,
#    'amount1': 22000000000}),
#   'event': 'IncreaseLiquidity',
#   'logIndex': 187,
#   'transactionIndex': 89,
#   'transactionHash': HexBytes('0x7d58e69198ecc1b4787d62efdf5f1d62c761931285900ae5f85ae7229c4028ef'),
#   'address': '0xC36442b4a4522E871399CD717aBDD847Ab11FE88',
#   'blockHash': HexBytes('0x05af871a485805cc2b573d1195e0024215ac0a391d5f25bf27752b0695664b98'),
#   'blockNumber': 12592585}),
#  AttributeDict({'args': AttributeDict({'tokenId': 29944,
#    'liquidity': 1642837340311745,
#    'amount0': 7940011921988859682,
#    'amount1': 24000000000}),
#   'event': 'IncreaseLiquidity',
#   'logIndex': 301,
#   'transactionIndex': 152,
#   'transactionHash': HexBytes('0x46660e0b21ca5f32407e29c104f8e95ee9f84f9bf531b77a5c866387673797e6'),
#   'address': '0xC36442b4a4522E871399CD717aBDD847Ab11FE88',
#   'blockHash': HexBytes('0x355325d76a08ae38d581b30774250ee624bca9b78b5fa9c5dc31fc4ae143ef3d'),
#   'blockNumber': 12604168}),
#  AttributeDict({'args': AttributeDict({'tokenId': 29944,
#    'liquidity': 1228194917577803,
#    'amount0': 7353680097419773176,
#    'amount1': 14500000000}),
#   'event': 'IncreaseLiquidity',
#   'logIndex': 381,
#   'transactionIndex': 96,
#   'transactionHash': HexBytes('0x29e3752c585309ece36772bd7ae4e11fe7880326d33cab4e4b9e059493a74472'),
#   'address': '0xC36442b4a4522E871399CD717aBDD847Ab11FE88',
#   'blockHash': HexBytes('0x99a218ef730391bb05e0605ec85f46e23c727f2c0055db3b4f5da8ec2a706de7'),
#   'blockNumber': 12618082}),
#  AttributeDict({'args': AttributeDict({'tokenId': 29944,
#    'liquidity': 1418891735353868,
#    'amount0': 6752394137967900456,
#    'amount1': 21000000000}),
#   'event': 'IncreaseLiquidity',
#   'logIndex': 153,
#   'transactionIndex': 65,
#   'transactionHash': HexBytes('0x8fb4fed39b13e975cc4005e3f7b924b8337eb49077ce3fd8ad32754c7de7d753'),
#   'address': '0xC36442b4a4522E871399CD717aBDD847Ab11FE88',
#   'blockHash': HexBytes('0x1e33170143b2627b4a7a90bd9ad0d73628960b2ba62d174cb72f4b94c13e5d83'),
#   'blockNumber': 12638980}),
#  AttributeDict({'args': AttributeDict({'tokenId': 29944,
#    'liquidity': 645872491236855,
#    'amount0': 3455116894464026269,
#    'amount1': 8600000000}),
#   'event': 'IncreaseLiquidity',
#   'logIndex': 298,
#   'transactionIndex': 188,
#   'transactionHash': HexBytes('0x138794dda63cb47fc1b805b2f7a05f6bc408280cf697d46aaa1d60f1a8e24ebe'),
#   'address': '0xC36442b4a4522E871399CD717aBDD847Ab11FE88',
#   'blockHash': HexBytes('0xef2d15c1fed04221a2975b19ccf3b2e757ad6c06aaff97fc4c027a6c2b5576f6'),
#   'blockNumber': 12650460}),
#  AttributeDict({'args': AttributeDict({'tokenId': 29944,
#    'liquidity': 2249944786419209,
#    'amount0': 15311663486654429053,
#    'amount1': 22500000000}),
#   'event': 'IncreaseLiquidity',
#   'logIndex': 180,
#   'transactionIndex': 110,
#   'transactionHash': HexBytes('0xc3883e36c56ea8c0ccb8dd03481944206136a783432d3eb2662747140e84fb0e'),
#   'address': '0xC36442b4a4522E871399CD717aBDD847Ab11FE88',
#   'blockHash': HexBytes('0xd2522007a48a0a14c160bfe727cfa45809fb59976f8940063b5be9837d5a9028'),
#   'blockNumber': 12672374}),
#  AttributeDict({'args': AttributeDict({'tokenId': 29944,
#    'liquidity': 6273720996772934,
#    'amount0': 46901752291658987152,
#    'amount1': 54069864420}),
#   'event': 'IncreaseLiquidity',
#   'logIndex': 161,
#   'transactionIndex': 89,
#   'transactionHash': HexBytes('0x39c9309e03f0a5d25222da003ced4a56bb19790826c75c346bc9d86ba73ad8a2'),
#   'address': '0xC36442b4a4522E871399CD717aBDD847Ab11FE88',
#   'blockHash': HexBytes('0x4c60db50ceebf87f1bcf81c7ba52e433f143d7d6355844f5b7dd9d35dacdeb07'),
#   'blockNumber': 12700552}),
#  AttributeDict({'args': AttributeDict({'tokenId': 29944,
#    'liquidity': 2005902083242809,
#    'amount0': 16499999999394219396,
#    'amount1': 14378896845}),
#   'event': 'IncreaseLiquidity',
#   'logIndex': 50,
#   'transactionIndex': 53,
#   'transactionHash': HexBytes('0x3df3b966b1df0a27b26f5cf67a0ddbc255896b5e307754ceee4e54b3f6158063'),
#   'address': '0xC36442b4a4522E871399CD717aBDD847Ab11FE88',
#   'blockHash': HexBytes('0x65c944aed6da3f4e15452260415dca3a2a038b2c37357b62a2daa91c3a728f2d'),
#   'blockNumber': 12714530}),
#  AttributeDict({'args': AttributeDict({'tokenId': 29944,
#    'liquidity': 1188323185154884,
#    'amount0': 7999999999568160904,
#    'amount1': 12068872170}),
#   'event': 'IncreaseLiquidity',
#   'logIndex': 159,
#   'transactionIndex': 98,
#   'transactionHash': HexBytes('0x9585219e59d6bc068ee19298e7c653079c0652c0118400cae0a2074d9499d662'),
#   'address': '0xC36442b4a4522E871399CD717aBDD847Ab11FE88',
#   'blockHash': HexBytes('0xfe3de5944b3b72def5d96253a05b84a2379243e4e017cae1ad245e511f63a320'),
#   'blockNumber': 12728092}),
#  AttributeDict({'args': AttributeDict({'tokenId': 29944,
#    'liquidity': 1333821996081399,
#    'amount0': 8999999999850452538,
#    'amount1': 13502827455}),
#   'event': 'IncreaseLiquidity',
#   'logIndex': 174,
#   'transactionIndex': 114,
#   'transactionHash': HexBytes('0x6295adeb836df3f9211fc649bd720150dd2b662d34492848a7e2e086e2e820a8'),
#   'address': '0xC36442b4a4522E871399CD717aBDD847Ab11FE88',
#   'blockHash': HexBytes('0x0d42b50e83c723ade8e9e13dc9eabad0ea215ed78c57b121d39f6a114d30dfb6'),
#   'blockNumber': 12741831}),
#  AttributeDict({'args': AttributeDict({'tokenId': 29944,
#    'liquidity': 5833111214615485,
#    'amount0': 39758791762115094445,
#    'amount1': 58200000000}),
#   'event': 'IncreaseLiquidity',
#   'logIndex': 225,
#   'transactionIndex': 64,
#   'transactionHash': HexBytes('0xbb4f3d9bd451ef5a4398187bfef878fa0ad006931f5d83c66c8fe1d72236de77'),
#   'address': '0xC36442b4a4522E871399CD717aBDD847Ab11FE88',
#   'blockHash': HexBytes('0x3c1e10b2e221981f11929694c089e8364e9064b120ef3f0c9091b144aa7d9390'),
#   'blockNumber': 12748898}),
#  AttributeDict({'args': AttributeDict({'tokenId': 29944,
#    'liquidity': 1089800507569142,
#    'amount0': 7368684684849195120,
#    'amount1': 11000000000}),
#   'event': 'IncreaseLiquidity',
#   'logIndex': 220,
#   'transactionIndex': 134,
#   'transactionHash': HexBytes('0x52567dec4539af532da6f8bb6e221d362c7dcd1ed81768587d8f839b168772e2'),
#   'address': '0xC36442b4a4522E871399CD717aBDD847Ab11FE88',
#   'blockHash': HexBytes('0xb2fd89f944254e5234a2653ed697f463a13e09551652842c5f6053528f166dda'),
#   'blockNumber': 12752305}),
#  AttributeDict({'args': AttributeDict({'tokenId': 29944,
#    'liquidity': 1057620967920387,
#    'amount0': 6502036025669186823,
#    'amount1': 12100000000}),
#   'event': 'IncreaseLiquidity',
#   'logIndex': 80,
#   'transactionIndex': 39,
#   'transactionHash': HexBytes('0x521b8183bb0b95f6f3abba2967ecb9a499d91e54f5eb2150b681a44407b2a9cd'),
#   'address': '0xC36442b4a4522E871399CD717aBDD847Ab11FE88',
#   'blockHash': HexBytes('0xcd6559bc974482a1e5b7853fc1a2d578c77e7f39fcc3d0fc489ec53405b5084b'),
#   'blockNumber': 12765133}),
#  AttributeDict({'args': AttributeDict({'tokenId': 29944,
#    'liquidity': 1520770726000467,
#    'amount0': 10499999999928813536,
#    'amount1': 14889563921}),
#   'event': 'IncreaseLiquidity',
#   'logIndex': 71,
#   'transactionIndex': 66,
#   'transactionHash': HexBytes('0xac896cdb24762da0b2a100fdecc2e37e73c6b2fa196d635ced25e70330d2e30a'),
#   'address': '0xC36442b4a4522E871399CD717aBDD847Ab11FE88',
#   'blockHash': HexBytes('0x0bfceef8198c1553533b6022a9fc3c87a5a94667ec78ce4cd8060655fd144fae'),
#   'blockNumber': 12800208}),
#  AttributeDict({'args': AttributeDict({'tokenId': 29944,
#    'liquidity': 1941578531703005,
#    'amount0': 14999999999821130504,
#    'amount1': 15774806323}),
#   'event': 'IncreaseLiquidity',
#   'logIndex': 314,
#   'transactionIndex': 194,
#   'transactionHash': HexBytes('0x4862ff662978f7e1a533bc6008ed60efd8b5b0eb66a00456993c5efe0c35f7ff'),
#   'address': '0xC36442b4a4522E871399CD717aBDD847Ab11FE88',
#   'blockHash': HexBytes('0x4133897ae271a15524464885a99d74c4e3bce418296d16b11b2d35e57e9725cc'),
#   'blockNumber': 12835730}),
#  AttributeDict({'args': AttributeDict({'tokenId': 29944,
#    'liquidity': 1039178432680822,
#    'amount0': 8498857446723219962,
#    'amount1': 7541279535}),
#   'event': 'IncreaseLiquidity',
#   'logIndex': 128,
#   'transactionIndex': 43,
#   'transactionHash': HexBytes('0x5e1b8f9f561ef7ce6f1768990cd90a80e1488a34df8a933d60762977a3717ea9'),
#   'address': '0xC36442b4a4522E871399CD717aBDD847Ab11FE88',
#   'blockHash': HexBytes('0x21f3faa857ddcc9ebae0f00aa2474fcdcc7d8226e62c81d5a632f185673bc7b6'),
#   'blockNumber': 12854587}),
#  AttributeDict({'args': AttributeDict({'tokenId': 29944,
#    'liquidity': 753415730559900,
#    'amount0': 6487382382789606056,
#    'amount1': 4866932639}),
#   'event': 'IncreaseLiquidity',
#   'logIndex': 317,
#   'transactionIndex': 153,
#   'transactionHash': HexBytes('0xea5622d6946620ba00d7d4b92e3127eac1cfb5126b9f65a3ee1e5eb4214133e3'),
#   'address': '0xC36442b4a4522E871399CD717aBDD847Ab11FE88',
#   'blockHash': HexBytes('0x8ca1bc06dd93d80d5208d25018ca76cb4c38d24f6b82c8f8265a2a3f6e8e8fd3'),
#   'blockNumber': 12867588}),
#  AttributeDict({'args': AttributeDict({'tokenId': 29944,
#    'liquidity': 21183820679729549,
#    'amount0': 150999999999261127650,
#    'amount1': 197532919388}),
#   'event': 'IncreaseLiquidity',
#   'logIndex': 149,
#   'transactionIndex': 98,
#   'transactionHash': HexBytes('0xadab722a6589fb35d2e20567e6635ca8bca5cd4aa0ac4e56dfa0d056ba9aa85d'),
#   'address': '0xC36442b4a4522E871399CD717aBDD847Ab11FE88',
#   'blockHash': HexBytes('0xd683c259bc05f2c02df7ce6cc9c84691b390912c41110ea9b9de603457915957'),
#   'blockNumber': 12883467}),
#  AttributeDict({'args': AttributeDict({'tokenId': 29944,
#    'liquidity': 1309243134063730,
#    'amount0': 8999999999445588090,
#    'amount1': 12901868528}),
#   'event': 'IncreaseLiquidity',
#   'logIndex': 344,
#   'transactionIndex': 163,
#   'transactionHash': HexBytes('0xef9d79346ae4ef3c8a30b567fca7ebc311501ef22a0cef2b5de8a2d1bac05757'),
#   'address': '0xC36442b4a4522E871399CD717aBDD847Ab11FE88',
#   'blockHash': HexBytes('0x13b51ad52b8d6183b9bebc2d49329cf8e3dd2c68390057bb8142241774737603'),
#   'blockNumber': 12886107}),
#  AttributeDict({'args': AttributeDict({'tokenId': 29944,
#    'liquidity': 11377268564895751,
#    'amount0': 74499999999844337452,
#    'amount1': 120066494160}),
#   'event': 'IncreaseLiquidity',
#   'logIndex': 337,
#   'transactionIndex': 148,
#   'transactionHash': HexBytes('0x086354dd8b4dde37fc569122132bb9c4a19f6aabcd798cc133e278093d59212a'),
#   'address': '0xC36442b4a4522E871399CD717aBDD847Ab11FE88',
#   'blockHash': HexBytes('0xec1bf7c8d2ad2a29c3433fd86185b1fdde163557cc0387227d1285c70c6eb5b6'),
#   'blockNumber': 12905942}),
#  AttributeDict({'args': AttributeDict({'tokenId': 29944,
#    'liquidity': 1017703614706350,
#    'amount0': 6099999999820271636,
#    'amount1': 11999785514}),
#   'event': 'IncreaseLiquidity',
#   'logIndex': 201,
#   'transactionIndex': 111,
#   'transactionHash': HexBytes('0x24b43dd210fd69748f9b4fe79eed03dc66eec54a966ea2aae6cabb0362a33d3f'),
#   'address': '0xC36442b4a4522E871399CD717aBDD847Ab11FE88',
#   'blockHash': HexBytes('0x67ebc04f34b59c928edb61bcd003ac7373cdeee0e9502f54d3e8a4545fefa80d'),
#   'blockNumber': 12917666}),
#  AttributeDict({'args': AttributeDict({'tokenId': 29944,
#    'liquidity': 9776567084172631,
#    'amount0': 56499999999769683743,
#    'amount1': 120139574564}),
#   'event': 'IncreaseLiquidity',
#   'logIndex': 321,
#   'transactionIndex': 151,
#   'transactionHash': HexBytes('0x86413cf5dd04b9f5e9fab78b3e7ea7b04d1eb4ba5a578e7efd908ce3c8deb1bd'),
#   'address': '0xC36442b4a4522E871399CD717aBDD847Ab11FE88',
#   'blockHash': HexBytes('0xeaa88b23be85d1140c503c14dfc1995f17b4a13a1378b2b19dc79f0687295120'),
#   'blockNumber': 12926381}),
#  AttributeDict({'args': AttributeDict({'tokenId': 29944,
#    'liquidity': 15689568038848150,
#    'amount0': 81999999999710074803,
#    'amount1': 213656045873}),
#   'event': 'IncreaseLiquidity',
#   'logIndex': 170,
#   'transactionIndex': 97,
#   'transactionHash': HexBytes('0x0b57f8e450d7c87aa22d4468e11f9f33378a050ab17f4858987bebf38afc2ac5'),
#   'address': '0xC36442b4a4522E871399CD717aBDD847Ab11FE88',
#   'blockHash': HexBytes('0x5a8868eb6e0cb9be09e0d00d42cda32f064235da7714f785eaa0223dac6aaa4a'),
#   'blockNumber': 12930791}),
#  AttributeDict({'args': AttributeDict({'tokenId': 29944,
#    'liquidity': 8717226672745132,
#    'amount0': 40299999999973186184,
#    'amount1': 132106708971}),
#   'event': 'IncreaseLiquidity',
#   'logIndex': 136,
#   'transactionIndex': 73,
#   'transactionHash': HexBytes('0x33b4fe63b330bde78e09b88685acad39acf68e1d7c205927e447b9469025deea'),
#   'address': '0xC36442b4a4522E871399CD717aBDD847Ab11FE88',
#   'blockHash': HexBytes('0xd5c9ce320c065ef7683505ea9aa447a51338ba0010325ed744bde38db34d88ca'),
#   'blockNumber': 12937692}),
#  AttributeDict({'args': AttributeDict({'tokenId': 29944,
#    'liquidity': 1357468947047626,
#    'amount0': 6599999999803687638,
#    'amount1': 19730465577}),
#   'event': 'IncreaseLiquidity',
#   'logIndex': 96,
#   'transactionIndex': 88,
#   'transactionHash': HexBytes('0x195c871540c4d15257a94e1c365690c6d9ed7c8a629b691e58f9fa5d492075e3'),
#   'address': '0xC36442b4a4522E871399CD717aBDD847Ab11FE88',
#   'blockHash': HexBytes('0x5b2bb319053a0ef497f814a2d6a498b75d2c340e9fcb0ed9a7e5e2cace28d096'),
#   'blockNumber': 12943724}),
#  AttributeDict({'args': AttributeDict({'tokenId': 29944,
#    'liquidity': 1411723010797221,
#    'amount0': 7199999999901748534,
#    'amount1': 19667612950}),
#   'event': 'IncreaseLiquidity',
#   'logIndex': 238,
#   'transactionIndex': 104,
#   'transactionHash': HexBytes('0xd798e8db60c480a2c10ac8a51a4e6a8d141ba5bd2f84b6a0f3ba42f187d5720d'),
#   'address': '0xC36442b4a4522E871399CD717aBDD847Ab11FE88',
#   'blockHash': HexBytes('0x6a6ef222e314b6ebbc983c8b8498c63ec831f80e6a754aaf2e60b3fa6ae09a36'),
#   'blockNumber': 12958343}),
#  AttributeDict({'args': AttributeDict({'tokenId': 29944,
#    'liquidity': 2158744866979985,
#    'amount0': 7562449152969854937,
#    'amount1': 39450000000}),
#   'event': 'IncreaseLiquidity',
#   'logIndex': 261,
#   'transactionIndex': 104,
#   'transactionHash': HexBytes('0x8a24303189fa20d3dcd5f1f43354d619c2335c35301dc7440c0946c923c787bd'),
#   'address': '0xC36442b4a4522E871399CD717aBDD847Ab11FE88',
#   'blockHash': HexBytes('0x1766c11b0bfc3a603c4f7403bcbcc30bd2d82b926a30d2b60f1c0e1fdf2ead1e'),
#   'blockNumber': 12976631}),
#  AttributeDict({'args': AttributeDict({'tokenId': 29944,
#    'liquidity': 1267365243000284,
#    'amount0': 4506127861814141410,
#    'amount1': 22964984695}),
#   'event': 'IncreaseLiquidity',
#   'logIndex': 299,
#   'transactionIndex': 184,
#   'transactionHash': HexBytes('0x2c8ae8bfd3cc637694090b002918315de876b538ec83945e60206a1b7de9b962'),
#   'address': '0xC36442b4a4522E871399CD717aBDD847Ab11FE88',
#   'blockHash': HexBytes('0x55c14b8e093fca7a395c0f78c69e928b8c55fc76dbf616259fb254597404091d'),
#   'blockNumber': 12988749}),
#  AttributeDict({'args': AttributeDict({'tokenId': 29944,
#    'liquidity': 3104056104942497,
#    'amount0': 9914336073473033636,
#    'amount1': 59610000000}),
#   'event': 'IncreaseLiquidity',
#   'logIndex': 517,
#   'transactionIndex': 230,
#   'transactionHash': HexBytes('0xb5f0626df8e7c14077ef42076876e857fa7991bfc627d4434f385f8799f5af33'),
#   'address': '0xC36442b4a4522E871399CD717aBDD847Ab11FE88',
#   'blockHash': HexBytes('0x1ebf659ea465fd124a1cb9dd3f1d62b8fbaa196ee59a2c46d92780c8abe7311b'),
#   'blockNumber': 13010980}),
#  AttributeDict({'args': AttributeDict({'tokenId': 29944,
#    'liquidity': 3232175263316378,
#    'amount0': 8339385948276466564,
#    'amount1': 68350000000}),
#   'event': 'IncreaseLiquidity',
#   'logIndex': 333,
#   'transactionIndex': 213,
#   'transactionHash': HexBytes('0x607bb70b2cbaf669c5a21bae3bcff9b953abb39ddcb81eef82c2fe9f4e329fcb'),
#   'address': '0xC36442b4a4522E871399CD717aBDD847Ab11FE88',
#   'blockHash': HexBytes('0x12d1fd085cd0e6aadd4e3e2c0ef70288e6977c754b5d0db7f8f1277a8d747990'),
#   'blockNumber': 13027345}),
#  AttributeDict({'args': AttributeDict({'tokenId': 29944,
#    'liquidity': 2981121445964248,
#    'amount0': 9699999999856064653,
#    'amount1': 56705779631}),
#   'event': 'IncreaseLiquidity',
#   'logIndex': 262,
#   'transactionIndex': 122,
#   'transactionHash': HexBytes('0xb55f42632ac96407be59e581e76419e6da3cf8a708f648cc9b1554f87b3da796'),
#   'address': '0xC36442b4a4522E871399CD717aBDD847Ab11FE88',
#   'blockHash': HexBytes('0x98d53d286f35125133d4811e47808507efbe24a0998b118601bda2ec2f1dc3e6'),
#   'blockNumber': 13047223})]

# %%
res2
# Out:
# []

# %% [markdown]
# Query transaction hash (view on etherscan) - view the events.

# %%
dates = [endTime]
blockNumber_start = res[0]['blockNumber']
startTime = datetime.datetime.fromtimestamp(web3_connection.eth.get_block(blockNumber_start).timestamp)
startDate = (startTime+datetime.timedelta(1)).replace(minute=0, hour=0, second=0, microsecond=0)
dates = list(pd.date_range(startDate, endTime).to_pydatetime()) + [endTime]
for result in res:
    mint_date = datetime.datetime.fromtimestamp(web3_connection.eth.get_block(result['blockNumber']).timestamp)
    dates.append(mint_date)
dates = np.sort(list(set(dates)))

# %%
fees_USDC = []
fees_WETH = []
liquidity_USDC = []
liquidity_WETH = []
sqrtPriceX96_array = []

for date in dates:

    #Moralis: Get blocknumber from date
    #https://docs.moralis.io/web3-data-api/reference/get-date-to-block

    api_key = "zWUKbN72Ae3VcnbnUzXUg0wfIHUglQ5pGpGElmOgM2eMypBmaRB0DWwr2tDhk9HI"
    params = {
        "date": date,
        "chain": "eth",
    }

    result = evm_api.block.get_date_to_block(
        api_key=api_key,
        params=params,
    )

    position = NFT_POSITIONMANAGER_contract.functions.positions(tokenID).call(block_identifier=result['block'])
    lowerTick = position[5]
    upperTick = position[6]
    liquidity = position[7]
    feeGrowthInside0LastX128 = position[8]
    feeGrowthInside1LastX128 = position[9]

    feeGrowthGlobal0X128 = UNIV3_USDC_WETH_contract.functions.feeGrowthGlobal0X128().call(block_identifier=result['block'])
    feeGrowthGlobal1X128 = UNIV3_USDC_WETH_contract.functions.feeGrowthGlobal1X128().call(block_identifier=result['block'])
    UNIV3_USDC_WETH_contract_lowerTick = UNIV3_USDC_WETH_contract.functions.ticks(lowerTick).call(block_identifier=result['block'])
    feeGrowthOutside0X128_LowerTick = UNIV3_USDC_WETH_contract_lowerTick[2]
    feeGrowthOutside1X128_LowerTick = UNIV3_USDC_WETH_contract_lowerTick[3]
    UNIV3_USDC_WETH_contract_upperTick = UNIV3_USDC_WETH_contract.functions.ticks(upperTick).call(block_identifier=result['block'])
    feeGrowthOutside0X128_UpperTick = UNIV3_USDC_WETH_contract_upperTick[2]
    feeGrowthOutside1X128_UpperTick = UNIV3_USDC_WETH_contract_upperTick[3]
    slot0 = UNIV3_USDC_WETH_contract.functions.slot0().call(block_identifier=result['block'])
    sqrtPriceX96 = slot0[0]
    currentTick = slot0[1]

    if currentTick >= lowerTick:
        feeGrowthBelow0X128 = feeGrowthOutside0X128_LowerTick
        feeGrowthBelow1X128 = feeGrowthOutside1X128_LowerTick
    else:
        feeGrowthBelow0X128 = feeGrowthGlobal0X128 - feeGrowthOutside0X128_LowerTick
        feeGrowthBelow1X128 = feeGrowthGlobal1X128 - feeGrowthOutside1X128_LowerTick

    if currentTick < upperTick:
        feeGrowthAbove0X128 = feeGrowthOutside0X128_UpperTick
        feeGrowthAbove1X128 = feeGrowthOutside1X128_UpperTick
    else:
        feeGrowthAbove0X128 = feeGrowthGlobal0X128 - feeGrowthOutside0X128_UpperTick
        feeGrowthAbove1X128 = feeGrowthGlobal1X128 - feeGrowthOutside1X128_UpperTick

    fees0X128 = (feeGrowthGlobal0X128 - feeGrowthBelow0X128 - feeGrowthAbove0X128 - feeGrowthInside0LastX128) % 2**256
    fees1X128 = (feeGrowthGlobal1X128 - feeGrowthBelow1X128 - feeGrowthAbove1X128 - feeGrowthInside1LastX128) % 2**256

    tokensOwed0 = position[10]
    tokensOwed1 = position[11]

    fees_USDC.append(fees0X128/2**128*liquidity/10**decimals_USDC + tokensOwed0/10**decimals_USDC)
    fees_WETH.append(fees1X128/2**128*liquidity/10**decimals_WETH + tokensOwed1/10**decimals_WETH)

    if currentTick < lowerTick:
        liquidity_token0 = liquidity*(1/np.sqrt(1.0001**lowerTick) - 1/np.sqrt(1.0001**upperTick))
        liquidity_token1 = 0
    elif currentTick >= upperTick:
        liquidity_token0 = 0
        liquidity_token1 = liquidity*(np.sqrt(1.0001**upperTick) - np.sqrt(1.0001**lowerTick))
    else:
        liquidity_token0 = liquidity*(1/(sqrtPriceX96/2**96) - 1/np.sqrt(1.0001**upperTick))
        liquidity_token1 = liquidity*(sqrtPriceX96/2**96 - np.sqrt(1.0001**lowerTick))

    liquidity_USDC.append(liquidity_token0/10**decimals_USDC)
    liquidity_WETH.append(liquidity_token1/10**decimals_WETH)

    sqrtPriceX96_array.append(sqrtPriceX96)

# %%
fees_daily = pd.DataFrame()
fees_daily["Date"] = dates
fees_daily["Fees USDC"] = fees_USDC
fees_daily["Fees WETH"] = fees_WETH
fees_daily["Liquidity USDC added"] = 0
fees_daily["Liquidity WETH added"] = 0
fees_daily["Liquidity USDC"] = liquidity_USDC
fees_daily["Liquidity WETH"] = liquidity_WETH



for result in res:
    mint_date = datetime.datetime.fromtimestamp(web3_connection.eth.get_block(result['blockNumber']).timestamp)
    fees_daily.loc[fees_daily["Date"] == mint_date, "Liquidity USDC added"] = result['args']['amount0']/10**decimals_USDC
    fees_daily.loc[fees_daily["Date"] == mint_date, "Liquidity WETH added"] = result['args']['amount1']/10**decimals_WETH



if len(res2) > 0:
    if liquidity_end == 0:
        #update values for the block when LP is removed
        fees_daily.loc[fees_daily["Date"] == endTime, "Fees USDC"] = (amount0_collected - amount0_burned)/10**decimals_USDC
        fees_daily.loc[fees_daily["Date"] == endTime, "Fees WETH"] = (amount1_collected - amount1_burned)/10**decimals_WETH
        fees_daily.loc[fees_daily["Date"] == endTime, "Liquidity USDC"] = amount0_burned/10**decimals_USDC
        fees_daily.loc[fees_daily["Date"] == endTime, "Liquidity WETH"] = amount1_burned/10**decimals_WETH

fees_daily["Price WETH/USDC"] = 1/((np.array(sqrtPriceX96_array)/2**96)**2 * 10**(decimals_USDC-decimals_WETH))
fees_daily["Liquidity added USDC converted"] = fees_daily["Liquidity USDC added"] + fees_daily["Liquidity WETH added"] * fees_daily["Price WETH/USDC"]
fees_daily["Portfolio USDC converted"] = fees_daily["Fees USDC"] + fees_daily["Liquidity USDC"] + (fees_daily["Fees WETH"] + fees_daily["Liquidity WETH"])  * fees_daily["Price WETH/USDC"]
fees_daily["Fees USDC converted"] = fees_daily["Fees USDC"] + fees_daily["Fees WETH"] * fees_daily["Price WETH/USDC"]

# %%
display(fees_daily)
# Out:
#                    Date     Fees USDC     Fees WETH  Liquidity USDC added
# 0   2021-05-31 04:42:49  2.187491e+50  2.187491e+38          3.824487e+15  \
# 1   2021-06-01 00:00:00  2.187491e+50  2.187491e+38          0.000000e+00
# 2   2021-06-01 17:29:52  2.192968e+50  2.192968e+38          8.000000e+12
# 3   2021-06-02 00:00:00  2.192968e+50  2.192968e+38          0.000000e+00
# 4   2021-06-03 00:00:00  2.192968e+50  2.192968e+38          0.000000e+00
# ..                  ...           ...           ...                   ...
# 798 2023-07-03 00:00:00  2.602518e+50  2.602518e+38          0.000000e+00
# 799 2023-07-04 00:00:00  2.602518e+50  2.602518e+38          0.000000e+00
# 800 2023-07-05 00:00:00  2.602518e+50  2.602518e+38          0.000000e+00
# 801 2023-07-06 00:00:00  2.602518e+50  2.602518e+38          0.000000e+00
# 802 2023-07-06 13:21:41  2.602518e+50  2.602518e+38          0.000000e+00
#
#      Liquidity WETH added  Liquidity USDC  Liquidity WETH Price WETH/USDC
# 0            7.645664e-06             0.0        0.000020     2296.253502  \
# 1            0.000000e+00             0.0        0.000020     2701.014068
# 2            2.295204e-08             0.0        0.000020     2532.747089
# 3            0.000000e+00             0.0        0.000020     2631.472703
# 4            0.000000e+00             0.0        0.000020      2707.78983
# ..                    ...             ...             ...             ...
# 798          0.000000e+00             0.0        0.000024     1937.157934
# 799          0.000000e+00             0.0        0.000024     1954.625283
# 800          0.000000e+00             0.0        0.000024     1936.373349
# 801          0.000000e+00             0.0        0.000024     1911.517794
# 802          0.000000e+00             0.0        0.000024     1905.465707
#
#     Liquidity added USDC converted
# 0               3824486509842432.0  \
# 1                              0.0
# 2             7999999999998.472656
# 3                              0.0
# 4                              0.0
# ..                             ...
# 798                            0.0
# 799                            0.0
# 800                            0.0
# 801                            0.0
# 802                            0.0
#
#                               Portfolio USDC converted
# 0    2187490805635688860667901626474600349488242701...  \
# 1    2187490806521098844021448524643503858213051338...
# 2    2192968090476593644342733809085677933103514365...
# 3    2192968090693095807993688809746988332443738864...
# 4    2192968090860456828024224153373255267205105361...
# ..                                                 ...
# 798  2602518230788659067033447156036224300642568671...
# 799  2602518230834118249105542596103324219664450117...
# 800  2602518230786617040524922579026475827046212991...
# 801  2602518230721930160110049648071612056457670022...
# 802  2602518230706179223743747077763912225233054277...
#
#                                    Fees USDC converted
# 0    2187490805635688860667901626474600349488242701...
# 1    2187490806521098844021448524643503858213051338...
# 2    2192968090476593644342733809085677933103514365...
# 3    2192968090693095807993688809746988332443738864...
# 4    2192968090860456828024224153373255267205105361...
# ..                                                 ...
# 798  2602518230788659067033447156036224300642568671...
# 799  2602518230834118249105542596103324219664450117...
# 800  2602518230786617040524922579026475827046212991...
# 801  2602518230721930160110049648071612056457670022...
# 802  2602518230706179223743747077763912225233054277...
#
# [803 rows x 11 columns]

# %%
fees_daily[['Liquidity USDC added']].sum()
# Out:
# Liquidity USDC added    4.542208e+15
# dtype: float64

# %%
fees_daily[['Liquidity WETH added']].sum()
# Out:
# Liquidity WETH added    0.000009
# dtype: float64

# %%
fees_daily.to_csv(f'{tokenID}.csv')
